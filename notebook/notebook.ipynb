# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../artifacts/raw/data.csv')

# %%
df.sample(5)
# Out:
#               Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 46534   2010-06-05  Canberra      0.3     14.9       0.0          1.6
# 120870  2009-02-18     Perth     17.3     30.6       0.0          8.0
# 131788  2014-01-30    Hobart     13.2     24.2       0.0          7.2
# 98451   2014-07-30  Adelaide     12.7     17.3       3.2          0.4
# 24209   2009-02-20   Penrith     19.7     32.6       0.4          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# 46534        9.1         WNW           13.0        NaN  ...        93.0
# 120870      12.5         ESE           37.0          E  ...        62.0
# 131788      10.4         SSE           41.0        NNW  ...        54.0
# 98451        NaN         NNW           43.0         NW  ...        88.0
# 24209        NaN         SSE           39.0          N  ...        78.0
#
#         Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
# ...

# %%
df.shape
# Out:
# (145460, 23)

# %%
df.describe(include=["object"])
# Out:
#               Date  Location WindGustDir WindDir9am WindDir3pm RainToday  \
# count       145460    145460      135134     134894     141232    142199
# unique        3436        49          16         16         16         2
# top     2017-06-18  Canberra           W          N         SE        No
# freq            49      3436        9915      11758      10838    110319
#
#        RainTomorrow
# count        142193
# unique            2
# top              No
# freq         110316

# %%
df.describe()
# Out:
#              MinTemp        MaxTemp       Rainfall   Evaporation  \
# count  143975.000000  144199.000000  142199.000000  82670.000000
# mean       12.194034      23.221348       2.360918      5.468232
# std         6.398495       7.119049       8.478060      4.193704
# min        -8.500000      -4.800000       0.000000      0.000000
# 25%         7.600000      17.900000       0.000000      2.600000
# 50%        12.000000      22.600000       0.000000      4.800000
# 75%        16.900000      28.200000       0.800000      7.400000
# max        33.900000      48.100000     371.000000    145.000000
#
#            Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  75625.000000  135197.000000  143693.000000  142398.000000
# mean       7.611178      40.035230      14.043426      18.662657
# std        3.785483      13.607062       8.915375       8.809800
# min        0.000000       6.000000       0.000000       0.000000
# ...

# %%
#!pip install missingno
import missingno as msno

# %%
msno.bar(df, color='red')
# Out:
# <Axes: >

# %%
percent_missing = df.isnull().sum() * 100 / len(df)
percent_missing
# Out:
# Date              0.000000
# Location          0.000000
# MinTemp           1.020899
# MaxTemp           0.866905
# Rainfall          2.241853
# Evaporation      43.166506
# Sunshine         48.009762
# WindGustDir       7.098859
# WindGustSpeed     7.055548
# WindDir9am        7.263853
# WindDir3pm        2.906641
# WindSpeed9am      1.214767
# WindSpeed3pm      2.105046
# Humidity9am       1.824557
# Humidity3pm       3.098446
# Pressure9am      10.356799
# Pressure3pm      10.331363
# Cloud9am         38.421559
# Cloud3pm         40.807095
# Temp9am           1.214767
# Temp3pm           2.481094
# RainToday         2.241853
# RainTomorrow      2.245978
# dtype: float64

# %%
cols_to_drop = percent_missing[percent_missing >10].index
df.drop(columns=cols_to_drop, inplace=True)

# %%
print("Dropping columns with >10% missing values:", list(cols_to_drop))
# Out:
# Dropping columns with >10% missing values: ['Evaporation', 'Sunshine', 'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm']

# %%
# Drop rows where target variables are missing
df = df.dropna(subset=['RainTomorrow'])

# %%
df.shape
# Out:
# (142193, 17)

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.Date.dtype
# Out:
# dtype('<M8[ns]')

# %%
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month
df['Day'] = df['Date'].dt.day

# %%
df.drop("Date", axis=1, inplace=True)

# %%
df.shape
# Out:
# (142193, 19)

# %%
df.columns
# Out:
# Index(['Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'WindGustDir',
#        'WindGustSpeed', 'WindDir9am', 'WindDir3pm', 'WindSpeed9am',
#        'WindSpeed3pm', 'Humidity9am', 'Humidity3pm', 'Temp9am', 'Temp3pm',
#        'RainToday', 'RainTomorrow', 'Year', 'Month', 'Day'],
#       dtype='object')

# %%
categorical = []
numerical = []

for col in df.columns:
    if df[col].dtype=='object':
        categorical.append(col)
    else:
        numerical.append(col)

# %%
for col in df.columns:
    if col in numerical:
        df[col]= df[col].fillna(df[col].median())
    else:
        df[col] = df[col].fillna(df[col].mode()[0])

# %%
df.isna().sum().sum()
# Out:
# np.int64(0)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### EDA

# %%
# Calculate percentage and plot
plt.figure(figsize=(4,4))
df.RainTomorrow.value_counts(normalize=True).plot(
    kind='pie',
    autopct='%1.1f%%',           
    colors=["#09F8AD", "#DC12DC"], 
    startangle=90,               
    shadow=True,                              
    ylabel=''                
)

plt.title('RainTomorrow Distribution (TARGET VAR)')
plt.tight_layout()
plt.show()

# %%
# Calculate percentage and plot
plt.figure(figsize=(4,4))
df.RainToday.value_counts(normalize=True).plot(
    kind='pie',
    autopct='%1.1f%%',           
    colors=["#EA5454", "#2A8BEC"], 
    startangle=90,               
    shadow=True,                              
    ylabel=''                
)

plt.title('RainToday Distribution')
plt.tight_layout()
plt.show()

# %%
numerical= [col for col in numerical if col not in cols_to_drop]

# %%
# Compute correlation matrix
corr_matrix = df[numerical].corr()

# Create a mask for the upper triangle
mask = np.triu(np.ones_like(corr_matrix, dtype=bool))

# Set up the matplotlib figure
plt.figure(figsize=(10, 10))

# Draw the heatmap
sns.heatmap(
    corr_matrix,
    mask=mask,
    cmap="coolwarm",         # Strong contrast for high/low values
    annot=True,
    fmt=".2f",
    vmin=-1, vmax=1,         # Full correlation range
    linewidths=0.5,
    linecolor='orange',
    cbar_kws={"shrink": 0.8}
)

plt.title("Strong Correlation Heatmap (Numerical Features)")
plt.show()

# %%
sns.scatterplot(df['WindSpeed9am'])
plt.show()

# %%
rain_counts = df.groupby('Month')['Humidity3pm'].sum()

plt.figure(figsize=(10, 6))
plt.barh(rain_counts.index, rain_counts.values, color='skyblue')
plt.xlabel("Monthwise spread of Humidity")
plt.ylabel("Month")
plt.title("Humidity Count by Month")
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.barplot(data=df, x='WindGustDir',y='WindGustSpeed', hue='RainTomorrow', palette='cool')
# Out:
# <Axes: xlabel='WindGustDir', ylabel='WindGustSpeed'>

# %% [markdown]
# ### DATA PROCESSING

# %%
from sklearn.preprocessing import LabelEncoder

# %%
for col in categorical:
    label_encoder = LabelEncoder()
    df[col] = label_encoder.fit_transform(df[col])
    label_mapping = dict(zip(label_encoder.classes_,range(len(label_encoder.classes_))))
    print(label_mapping)
# Out:
# {'Adelaide': 0, 'Albany': 1, 'Albury': 2, 'AliceSprings': 3, 'BadgerysCreek': 4, 'Ballarat': 5, 'Bendigo': 6, 'Brisbane': 7, 'Cairns': 8, 'Canberra': 9, 'Cobar': 10, 'CoffsHarbour': 11, 'Dartmoor': 12, 'Darwin': 13, 'GoldCoast': 14, 'Hobart': 15, 'Katherine': 16, 'Launceston': 17, 'Melbourne': 18, 'MelbourneAirport': 19, 'Mildura': 20, 'Moree': 21, 'MountGambier': 22, 'MountGinini': 23, 'Newcastle': 24, 'Nhil': 25, 'NorahHead': 26, 'NorfolkIsland': 27, 'Nuriootpa': 28, 'PearceRAAF': 29, 'Penrith': 30, 'Perth': 31, 'PerthAirport': 32, 'Portland': 33, 'Richmond': 34, 'Sale': 35, 'SalmonGums': 36, 'Sydney': 37, 'SydneyAirport': 38, 'Townsville': 39, 'Tuggeranong': 40, 'Uluru': 41, 'WaggaWagga': 42, 'Walpole': 43, 'Watsonia': 44, 'Williamtown': 45, 'Witchcliffe': 46, 'Wollongong': 47, 'Woomera': 48}
# {'E': 0, 'ENE': 1, 'ESE': 2, 'N': 3, 'NE': 4, 'NNE': 5, 'NNW': 6, 'NW': 7, 'S': 8, 'SE': 9, 'SSE': 10, 'SSW': 11, 'SW': 12, 'W': 13, 'WNW': 14, 'WSW': 15}
# ...

# %%
df.head(3)
# Out:
#    Location  MinTemp  MaxTemp  Rainfall  WindGustDir  WindGustSpeed  \
# 0         2     13.4     22.9       0.6           13           44.0
# 1         2      7.4     25.1       0.0           14           44.0
# 2         2     12.9     25.7       0.0           15           46.0
#
#    WindDir9am  WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am  \
# 0          13          14          20.0          24.0         71.0
# 1           6          15           4.0          22.0         44.0
# 2          13          15          19.0          26.0         38.0
#
#    Humidity3pm  Temp9am  Temp3pm  RainToday  RainTomorrow  Year  Month  Day
# 0         22.0     16.9     21.8          0             0  2008     12    1
# 1         25.0     17.2     24.3          0             0  2008     12    2
# 2         30.0     21.0     23.2          0             0  2008     12    3

# %% [markdown]
# RainToday- Strong temporal link: If it rained today, there's a higher chance it might rain tomorrow due to weather patterns, so its a input feature.

# %%
X = df.drop('RainTomorrow', axis=1)
y = df.RainTomorrow

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=0.2, stratify=y, random_state=90)

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(random_state=42)
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
feature_importance_df = pd.DataFrame({'Feature': X_train.columns, 
                                'importance':model.feature_importances_ })

feat_imp_df = feature_importance_df.sort_values('importance', ascending=False)
feat_imp_df['cum_imp'] = np.cumsum(feat_imp_df['importance'])

# %%
feat_imp_df
# Out:
#           Feature  importance   cum_imp
# 11    Humidity3pm    0.201568  0.201568
# 5   WindGustSpeed    0.073301  0.274869
# 10    Humidity9am    0.069385  0.344255
# 3        Rainfall    0.064898  0.409152
# 1         MinTemp    0.060861  0.470013
# 13        Temp3pm    0.059127  0.529140
# 2         MaxTemp    0.055963  0.585103
# 12        Temp9am    0.055108  0.640211
# 17            Day    0.044774  0.684985
# 0        Location    0.043247  0.728232
# 9    WindSpeed3pm    0.042086  0.770317
# 8    WindSpeed9am    0.038379  0.808697
# 6      WindDir9am    0.035956  0.844653
# 7      WindDir3pm    0.035839  0.880493
# 4     WindGustDir    0.034579  0.915071
# 15           Year    0.031897  0.946969
# 16          Month    0.031382  0.978351
# 14      RainToday    0.021649  1.000000

# %%
from sklearn.metrics import accuracy_score, precision_score, f1_score,recall_score

# %%
y_pred= model.predict(X_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.8484827173951264

# %%
f1_score(y_test,y_pred)
# Out:
# 0.5829865479531597

# %%
import xgboost as xgb

# %%
df.RainTomorrow.unique()
# Out:
# array([0, 1])

# %%
df.RainTomorrow.isna().sum()
# Out:
# np.int64(0)

# %%
# Calculate scale_pos_weight
neg, pos = np.bincount(df['RainTomorrow'])
model = xgb.XGBClassifier(scale_pos_weight=neg/pos, eval_metric='auc')

# %%
model.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='auc', feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
model.score(X_train,y_train)
# Out:
# 0.8462032104365561

# %%
model.score(X_test,y_test)
# Out:
# 0.8109286543127395

# %%
y_pred = model.predict(X_test)

# %%
print("Accuracy: ",accuracy_score(y_test,y_pred))
# Out:
# Accuracy:  0.8109286543127395

# %%
print("F1 score : ", f1_score(y_test,y_pred))
# Out:
# F1 score :  0.6400214233112406

# %%
from sklearn.model_selection import GridSearchCV
scale_pos_weight=neg/pos

param_grid = {
    'n_estimators': [100,200,500,1000],
    'max_depth': [3, 5, 7],
    'learning_rate': [0.001, 0.01, 0.1, 0.2],
    'n_estimators': [100, 300],
    'subsample': [0.8, 1.0],
    'scale_pos_weight': [scale_pos_weight]
}

grid = GridSearchCV(xgb.XGBClassifier(), param_grid, scoring='roc_auc', cv=2)
grid.fit(X_train, y_train)
print("Best params:", grid.best_params_)
# Out:
# Best params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 300, 'scale_pos_weight': np.float64(3.5122592224608185), 'subsample': 0.8}

# %%
print("Best params:", grid.best_params_)
# Out:
# Best params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 300, 'scale_pos_weight': np.float64(3.5122592224608185), 'subsample': 0.8}

# %%
y_grid_pred = grid.predict(X_test)
print("Accuracy : ", accuracy_score(y_test, y_grid_pred))
print("F1-score : ", f1_score(y_test, y_grid_pred))
# Out:
# Accuracy :  0.809148377015413
# F1-score :  0.6363513330626607

# %%
from sklearn.ensemble import GradientBoostingClassifier, AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier

# %%
classifiers ={
    "Random_Forest": RandomForestClassifier(random_state=42),
    "Gradient Boosting" : GradientBoostingClassifier(random_state=42),
    "Decision Tree": DecisionTreeClassifier(random_state=42),
    "XGBoost" : XGBClassifier(random_state=42),
    "AdaBoostClassifier" : AdaBoostClassifier(random_state=42),
    "lightGBM" : LGBMClassifier(random_state=42)
    }

# %%
metrics ={
    "Model" :[],
    "Accuracy":[],
    "Precision": [],
    "Recall": [],
    "F1 score": []
}

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
for model_name, classifier in classifiers.items():
    classifier.fit(X_train,y_train)

    y_pred = classifier.predict(X_test)

    accuracy = accuracy_score(y_test,y_pred)
    precision = precision_score(y_test,y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test,y_pred)

    metrics["Model"].append(model_name)
    metrics["Accuracy"].append(accuracy)
    metrics["Precision"].append(precision)
    metrics["Recall"].append(recall)
    metrics["F1 score"].append(f1)
# Out:
# [LightGBM] [Info] Number of positive: 24961, number of negative: 87668
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.011407 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1775
# [LightGBM] [Info] Number of data points in the train set: 112629, number of used features: 18
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.221621 -> initscore=-1.256242
# [LightGBM] [Info] Start training from score -1.256242

# %%
metrics_df= pd.DataFrame(metrics)
metrics_df
# Out:
#                 Model  Accuracy  Precision    Recall  F1 score
# 0       Random_Forest  0.849066   0.754216  0.473077  0.581446
# 1   Gradient Boosting  0.844840   0.738953  0.463622  0.569769
# 2       Decision Tree  0.777790   0.498687  0.517308  0.507827
# 3             XGBoost  0.853399   0.741758  0.519231  0.610860
# 4  AdaBoostClassifier  0.833404   0.692902  0.445833  0.542565
# 5            lightGBM  0.852333   0.748212  0.502885  0.601495
